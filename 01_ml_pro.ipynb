# %% [markdown]
# <a href="https://colab.research.google.com/github/KameMassy/ML_projects/blob/main/01_ml_pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %% [markdown]
# #Done preprocessing

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %% [markdown]
# #We are using logistic regression
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Extract input and output cols

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X.head()
# Out:
#    cgpa     iq
# 0   6.8  123.0
# 1   5.9  106.0
# 2   5.3  121.0
# 3   7.4  132.0
# 4   5.8  142.0

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: placement, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %% [markdown]
# #Train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.1)

# %% [markdown]
# #scaling the value

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.39914013,  0.86727315],
#        [ 0.31340597, -0.22163036],
#        [ 0.0562035 , -1.48376852],
#        [ 1.34221585,  0.07534332],
#        [-0.20099897,  1.01575999],
#        [-0.02953065, -1.45902072],
#        [-0.71540391,  2.45113281],
#        [-1.82994794, -0.39486501],
#        [ 1.51368416, -0.27112598],
#        [ 0.82781091,  0.3475692 ],
#        [-0.11526481, -0.46910843],
#        [-0.97260638,  1.75819421],
#        [ 0.6563426 ,  0.39706482],
#        [-1.14407469, -0.09789133],
#        [ 0.82781091,  1.23849026],
#        [ 0.6563426 , -0.04839571],
#        [ 1.17074754,  0.17433455],
#        [ 1.25648169,  0.81777754],
#        [ 1.77088663,  0.59504727],
#        [-0.97260638, -0.12263913],
#        [-0.28673312,  0.44656043],
#        [ 0.6563426 , -0.86507335],
#        [ 0.91354507, -1.90448124],
#        [ 0.74207676,  0.3475692 ],
#        [ 1.94235495,  1.06525561],
#        [ 1.08501338,  0.29807359],
#        [-0.20099897,  0.42181262],
#        [-0.97260638, -1.58275975],
#        [ 0.0562035 , -0.54335185],
#        [-1.05834053,  1.09000341],
#        [-1.14407469, -1.80549002],
#        [-0.62966975, -0.09789133],
#        [ 0.74207676,  0.32282139],
#        [-1.05834053, -0.32062159],
#        [-0.71540391,  0.89202096],
#        [-0.02953065, -0.0236479 ],
#        [-0.88687222, -1.53326414],
#        [ 0.0562035 ,  0.76828192],
#        [ 1.77088663,  1.01575999],
#        [ 0.22767182,  0.05059552],
#        [ 1.08501338, -0.96406457],
#        [ 0.48487429, -0.12263913],
#        [-0.97260638,  0.64454289],
#        [-1.14407469, -0.93931677],
#        [-0.71540391,  0.17433455],
#        [-0.54393559, -0.44436063],
#        [ 0.0562035 , -1.08780361],
#        [-2.34435288,  1.43647271],
#        [ 0.48487429,  0.32282139],
#        [-0.28673312,  0.17433455],
#        [ 0.57060844,  0.71878631],
#        [ 1.25648169,  0.12483894],
#        [-0.80113806,  0.07534332],
#        [ 1.34221585, -0.88982115],
#        [-1.05834053,  0.94151657],
#        [-1.74421379, -0.61759527],
#        [-1.05834053,  0.39706482],
#        [-0.62966975, -0.27112598],
#        [ 1.08501338, -1.85498563],
#        [-0.97260638,  0.74353412],
#        [ 0.39914013,  0.12483894],
#        [-1.48701132,  1.85718544],
#        [-0.71540391, -0.3701172 ],
#        [ 0.57060844,  1.41172491],
#        [ 0.6563426 , -0.32062159],
#        [-2.17288457,  2.67386307],
#        [-0.80113806,  1.26323806],
#        [-1.22980885,  0.52080385],
#        [-0.88687222, -0.17213475],
#        [ 2.11382326, -0.12263913],
#        [ 1.25648169, -1.58275975],
#        [ 1.68515248, -1.13729922],
#        [ 0.82781091, -1.50851633],
#        [ 0.22767182, -0.54335185],
#        [-1.74421379, -1.23629045],
#        [ 0.91354507,  0.64454289],
#        [-0.02953065, -1.97872467],
#        [ 0.82781091,  1.83243763],
#        [-0.88687222, -0.84032554],
#        [ 0.39914013, -2.17670712],
#        [-0.02953065,  0.59504727],
#        [ 1.08501338, -0.22163036],
#        [-0.28673312,  1.09000341],
#        [-0.28673312,  0.37231701],
#        [ 0.74207676, -0.7165865 ],
#        [-0.97260638,  0.22383017],
#        [ 0.82781091, -0.32062159],
#        [ 0.22767182,  0.07534332],
#        [-0.80113806, -1.45902072],
#        [-0.54393559,  0.24857797]])

# %%
X_test = scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[ 0.54738055, -0.3015891 ],
#        [ 0.82107083,  0.05900656],
#        [-1.64214165, -2.26847451],
#        [-0.54738055, -0.69496618],
#        [-1.64214165,  1.23913781],
#        [-0.27369028,  0.91132358],
#        [ 0.68422569,  0.68185361],
#        [-0.27369028,  0.09178799],
#        [ 1.0947611 ,  0.97688642],
#        [ 1.23160624, -0.69496618]])

# %% [markdown]
# #Train the model

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # 5. Evaluate the model/model selection

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
#!pip install mlxtend

# %%
#from mlxtend.plotting import plot_decision_regions

# %%
#plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
